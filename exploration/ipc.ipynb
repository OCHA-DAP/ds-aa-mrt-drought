# %% [markdown]
# # IPC

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2

# %%
from io import BytesIO
from datetime import datetime

import ocha_stratus as stratus
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

from src.datasources import ipc
from src.constants import *

# %%
adm2 = stratus.datasources.codab.load_codab_from_fieldmaps(
    iso3=ISO3, admin_level=2
)

# %%
adm2.plot()
# Out:
# <Axes: >

# %%
adm1 = stratus.datasources.codab.load_codab_from_fieldmaps(
    iso3=ISO3, admin_level=1
)

# %%
adm1
# Out:
#      fid          adm1_id adm1_src           adm1_name adm1_name1 adm1_name2  \
# 0   2029  MRT-20240402-01     MR01        Hodh Chargui       None       None
# 1   2030  MRT-20240402-02     MR02      Hodh El Gharbi       None       None
# 2   2031  MRT-20240402-03     MR03              Assaba       None       None
# 3   2032  MRT-20240402-04     MR04              Gorgol       None       None
# 4   2033  MRT-20240402-05     MR05              Brakna       None       None
# 5   2034  MRT-20240402-06     MR06              Trarza       None       None
# 6   2035  MRT-20240402-07     MR07               Adrar       None       None
# 7   2036  MRT-20240402-08     MR08  Dakhlet Nouadhibou       None       None
# 8   2037  MRT-20240402-09     MR09              Tagant       None       None
# 9   2038  MRT-20240402-10     MR10          Guidimagha       None       None
# 10  2039  MRT-20240402-11     MR11       Tiris Zemmour       None       None
# 11  2040  MRT-20240402-12     MR12             Inchiri       None       None
# 12  2041  MRT-20240402-13     MR13    Nouakchott Ouest       None       None
# 13  2042  MRT-20240402-14     MR14     Nouakchott Nord       None       None
# 14  2043  MRT-20240402-15     MR15      Nouakchott Sud       None       None
#
#          adm0_id adm0_src   adm0_name  adm0_name1  ...          region2_nm  \
# 0   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 1   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 2   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 3   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 4   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 5   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 6   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 7   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 8   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 9   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 10  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 11  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 12  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 13  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 14  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
#
#     region1_cd region1_nm status_cd status_nm    wld_date  wld_update  \
# 0            2     Africa         1     State  2025-02-24  2025-07-29
# 1            2     Africa         1     State  2025-02-24  2025-07-29
# 2            2     Africa         1     State  2025-02-24  2025-07-29
# 3            2     Africa         1     State  2025-02-24  2025-07-29
# 4            2     Africa         1     State  2025-02-24  2025-07-29
# 5            2     Africa         1     State  2025-02-24  2025-07-29
# 6            2     Africa         1     State  2025-02-24  2025-07-29
# 7            2     Africa         1     State  2025-02-24  2025-07-29
# 8            2     Africa         1     State  2025-02-24  2025-07-29
# 9            2     Africa         1     State  2025-02-24  2025-07-29
# 10           2     Africa         1     State  2025-02-24  2025-07-29
# 11           2     Africa         1     State  2025-02-24  2025-07-29
# 12           2     Africa         1     State  2025-02-24  2025-07-29
# 13           2     Africa         1     State  2025-02-24  2025-07-29
# 14           2     Africa         1     State  2025-02-24  2025-07-29
#
#    wld_view wld_notes                                           geometry
# 0      intl      None  MULTIPOLYGON (((-5.58747 16.48706, -5.60347 16...
# 1      intl      None  MULTIPOLYGON (((-10.0498 15.36374, -10.04654 1...
# 2      intl      None  MULTIPOLYGON (((-10.58564 15.42909, -10.62056 ...
# 3      intl      None  MULTIPOLYGON (((-12.75489 15.13907, -12.75488 ...
# 4      intl      None  MULTIPOLYGON (((-13.70743 16.15393, -13.68799 ...
# 5      intl      None  MULTIPOLYGON (((-16.2873 16.50018, -16.2871 16...
# 6      intl      None  MULTIPOLYGON (((-13.33236 19.00029, -13.20623 ...
# 7      intl      None  MULTIPOLYGON (((-16.48909 19.62472, -16.48869 ...
# 8      intl      None  MULTIPOLYGON (((-11.52933 17.17609, -11.59948 ...
# 9      intl      None  MULTIPOLYGON (((-11.99044 14.76314, -11.98911 ...
# 10     intl      None  MULTIPOLYGON (((-6.56009 24.89802, -6.56685 24...
# 11     intl      None  MULTIPOLYGON (((-15.74314 19.27873, -15.77649 ...
# 12     intl      None  MULTIPOLYGON (((-16.02542 18.05935, -16.02164 ...
# 13     intl      None  MULTIPOLYGON (((-15.84458 18.0312, -15.84439 1...
# 14     intl      None  MULTIPOLYGON (((-16.03647 17.82237, -16.03593 ...
#
# [15 rows x 39 columns]

# %%
adm1.plot()
# Out:
# <Axes: >

# %%
df_test = ipc.process_all_subnational_ipc_analyses_from_population()

# %%
df_test
# Out:
#       top_id                            top_title top_country top_condition  \
# 0   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 1   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 2   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 3   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 4   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 5   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 6   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 7   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 8   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 9   79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 10  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 11  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 12  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 13  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 14  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 15  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 16  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 17  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 18  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 19  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 20  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 21  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 22  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 23  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 24  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 25  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 26  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 27  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 28  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 29  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 30  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 31  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 32  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 33  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 34  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 35  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 36  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 37  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 38  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 39  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 40  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 41  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 42  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 43  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 44  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 45  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 46  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 47  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 48  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 49  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 50  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 51  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 52  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 53  79065821  Cadre Harmonisé Analysis March 2025          MR             A
# 54  79065821  Cadre Harmonisé Analysis March 2025          MR             A
#
#    top_analysis_date top_current_period_dates top_projected_period_dates  \
# 0           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 1           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 2           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 3           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 4           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 5           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 6           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 7           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 8           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 9           Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 10          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 11          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 12          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 13          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 14          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 15          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 16          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 17          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 18          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 19          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 20          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 21          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 22          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 23          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 24          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 25          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 26          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 27          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 28          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 29          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 30          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 31          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 32          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 33          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 34          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 35          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 36          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 37          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 38          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 39          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 40          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 41          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 42          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 43          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 44          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 45          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 46          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 47          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 48          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 49          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 50          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 51          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 52          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 53          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
# 54          Mar 2025      Mar 2025 - May 2025        Jun 2025 - Aug 2025
#
#    top_second_projected_period_dates top_view_level top_ipc_period  ...  \
# 0                                              area              C  ...
# 1                                              area              C  ...
# 2                                              area              C  ...
# 3                                              area              C  ...
# 4                                              area              C  ...
# 5                                              area              C  ...
# 6                                              area              C  ...
# 7                                              area              C  ...
# 8                                              area              C  ...
# 9                                              area              C  ...
# 10                                             area              C  ...
# 11                                             area              C  ...
# 12                                             area              C  ...
# 13                                             area              C  ...
# 14                                             area              C  ...
# 15                                             area              C  ...
# 16                                             area              C  ...
# 17                                             area              C  ...
# 18                                             area              C  ...
# 19                                             area              C  ...
# 20                                             area              C  ...
# 21                                             area              C  ...
# 22                                             area              C  ...
# 23                                             area              C  ...
# 24                                             area              C  ...
# 25                                             area              C  ...
# 26                                             area              C  ...
# 27                                             area              C  ...
# 28                                             area              C  ...
# 29                                             area              C  ...
# 30                                             area              C  ...
# 31                                             area              C  ...
# 32                                             area              C  ...
# 33                                             area              C  ...
# 34                                             area              C  ...
# 35                                             area              C  ...
# 36                                             area              C  ...
# 37                                             area              C  ...
# 38                                             area              C  ...
# 39                                             area              C  ...
# 40                                             area              C  ...
# 41                                             area              C  ...
# 42                                             area              C  ...
# 43                                             area              C  ...
# 44                                             area              C  ...
# 45                                             area              C  ...
# 46                                             area              C  ...
# 47                                             area              C  ...
# 48                                             area              C  ...
# 49                                             area              C  ...
# 50                                             area              C  ...
# 51                                             area              C  ...
# 52                                             area              C  ...
# 53                                             area              C  ...
# 54                                             area              C  ...
#
#     area_phase2_percentage_projected  area_phase3_population_projected  \
# 0                             0.2000                               930
# 1                             0.2000                              5614
# 2                             0.2600                               256
# 3                             0.3700                             27134
# 4                             0.2200                              5828
# 5                             0.3000                              2783
# 6                             0.3000                             27924
# 7                             0.2400                              5470
# 8                             0.2400                             19237
# 9                             0.2500                              2568
# 10                            0.2700                             13536
# 11                            0.1800                              4956
# 12                            0.4000                             26144
# 13                            0.2300                              4629
# 14                            0.2200                              5194
# 15                            0.2000                               327
# 16                            0.2200                              3315
# 17                            0.2500                               833
# 18                            0.2001                               268
# 19                            0.2100                              2948
# 20                            0.2200                              4909
# 21                            0.3200                              8564
# 22                            0.3000                              3954
# 23                            0.2300                             10170
# 24                            0.2300                              8109
# 25                            0.2100                              5973
# 26                            0.3000                             12056
# 27                            0.2500                              6344
# 28                            0.2100                              5310
# 29                            0.2400                              1736
# 30                            0.2300                             17390
# 31                            0.2600                             20290
# 32                            0.1600                              3965
# 33                            0.3000                              5248
# 34                            0.1700                              1404
# 35                            0.2700                              8448
# 36                            0.2500                               738
# 37                            0.2100                              4020
# 38                            0.2700                              4688
# 39                            0.3000                             12586
# 40                            0.1900                             25339
# 41                            0.1700                              8666
# 42                            0.3000                             27817
# 43                            0.3100                             20905
# 44                            0.2700                             14272
# 45                            0.3100                              2257
# 46                            0.2300                              7647
# 47                            0.2300                              7323
# 48                            0.2400                             24652
# 49                            0.4000                               988
# 50                            0.2500                              5794
# 51                            0.3000                              5233
# 52                            0.3200                             61447
# 53                            0.1700                             50193
# 54                            0.1900                             10244
#
#     area_phase3_percentage_projected  area_phase4_population_projected  \
# 0                             0.0800                                 0
# 1                             0.0900                                 0
# 2                             0.0499                                 0
# 3                             0.2200                              1233
# 4                             0.0800                                 0
# 5                             0.2200                               127
# 6                             0.2300                              2428
# 7                             0.0700                                 0
# 8                             0.2100                                 0
# 9                             0.2000                                 0
# 10                            0.1200                                 0
# 11                            0.0500                               991
# 12                            0.2300                              1137
# 13                            0.0500                               926
# 14                            0.0900                               577
# 15                            0.0499                                 0
# 16                            0.0700                                 0
# 17                            0.0600                                 0
# 18                            0.0699                                 0
# 19                            0.1000                                 0
# 20                            0.0500                                 0
# 21                            0.1800                                 0
# 22                            0.0900                                 0
# 23                            0.1300                                 0
# 24                            0.0600                                 0
# 25                            0.0700                                 0
# 26                            0.2200                                 0
# 27                            0.1200                                 0
# 28                            0.0700                                 0
# 29                            0.0400                                 0
# 30                            0.2200                                 0
# 31                            0.1100                                 0
# 32                            0.0800                                 0
# 33                            0.1200                                 0
# 34                            0.0400                                 0
# 35                            0.1200                                 0
# 36                            0.0300                                 0
# 37                            0.0600                               670
# 38                            0.1400                                 0
# 39                            0.2200                               572
# 40                            0.2100                              1207
# 41                            0.2100                                 0
# 42                            0.2100                                 0
# 43                            0.2300                                 0
# 44                            0.2100                               680
# 45                            0.2100                               107
# 46                            0.0700                                 0
# 47                            0.0500                                 0
# 48                            0.2100                              1174
# 49                            0.2200                                45
# 50                            0.1000                                 0
# 51                            0.1000                                 0
# 52                            0.1000                                 0
# 53                            0.0800                                 0
# 54                            0.0500                                 0
#
#     area_phase4_percentage_projected  area_phase5_population_projected  \
# 0                               0.00                                 0
# 1                               0.00                                 0
# 2                               0.00                                 0
# 3                               0.01                                 0
# 4                               0.00                                 0
# 5                               0.01                                 0
# 6                               0.02                                 0
# 7                               0.00                                 0
# 8                               0.00                                 0
# 9                               0.00                                 0
# 10                              0.00                                 0
# 11                              0.01                                 0
# 12                              0.01                                 0
# 13                              0.01                                 0
# 14                              0.01                                 0
# 15                              0.00                                 0
# 16                              0.00                                 0
# 17                              0.00                                 0
# 18                              0.00                                 0
# 19                              0.00                                 0
# 20                              0.00                                 0
# 21                              0.00                                 0
# 22                              0.00                                 0
# 23                              0.00                                 0
# 24                              0.00                                 0
# 25                              0.00                                 0
# 26                              0.00                                 0
# 27                              0.00                                 0
# 28                              0.00                                 0
# 29                              0.00                                 0
# 30                              0.00                                 0
# 31                              0.00                                 0
# 32                              0.00                                 0
# 33                              0.00                                 0
# 34                              0.00                                 0
# 35                              0.00                                 0
# 36                              0.00                                 0
# 37                              0.01                                 0
# 38                              0.00                                 0
# 39                              0.01                                 0
# 40                              0.01                                 0
# 41                              0.00                                 0
# 42                              0.00                                 0
# 43                              0.00                                 0
# 44                              0.01                                 0
# 45                              0.01                                 0
# 46                              0.00                                 0
# 47                              0.00                                 0
# 48                              0.01                                 0
# 49                              0.01                                 0
# 50                              0.00                                 0
# 51                              0.00                                 0
# 52                              0.00                                 0
# 53                              0.00                                 0
# 54                              0.00                                 0
#
#     area_phase5_percentage_projected  area_overall_phase  \
# 0                                  0                   1
# 1                                  0                   1
# 2                                  0                   1
# 3                                  0                   2
# 4                                  0                   1
# 5                                  0                   2
# 6                                  0                   2
# 7                                  0                   1
# 8                                  0                   2
# 9                                  0                   2
# 10                                 0                   2
# 11                                 0                   1
# 12                                 0                   2
# 13                                 0                   1
# 14                                 0                   2
# 15                                 0                   1
# 16                                 0                   1
# 17                                 0                   1
# 18                                 0                   1
# 19                                 0                   2
# 20                                 0                   1
# 21                                 0                   2
# 22                                 0                   2
# 23                                 0                   2
# 24                                 0                   2
# 25                                 0                   1
# 26                                 0                   2
# 27                                 0                   2
# 28                                 0                   1
# 29                                 0                   1
# 30                                 0                   2
# 31                                 0                   2
# 32                                 0                   1
# 33                                 0                   2
# 34                                 0                   1
# 35                                 0                   2
# 36                                 0                   1
# 37                                 0                   1
# 38                                 0                   2
# 39                                 0                   2
# 40                                 0                   2
# 41                                 0                   2
# 42                                 0                   2
# 43                                 0                   2
# 44                                 0                   2
# 45                                 0                   2
# 46                                 0                   2
# 47                                 0                   2
# 48                                 0                   2
# 49                                 0                   2
# 50                                 0                   2
# 51                                 0                   1
# 52                                 0                   1
# 53                                 0                   1
# 54                                 0                   1
#
#     area_overall_phase_projected  area_estimated_population_second_projected
# 0                              2                                           0
# 1                              2                                           0
# 2                              2                                           0
# 3                              3                                           0
# 4                              2                                           0
# 5                              3                                           0
# 6                              3                                           0
# 7                              2                                           0
# 8                              3                                           0
# 9                              3                                           0
# 10                             2                                           0
# 11                             2                                           0
# 12                             3                                           0
# 13                             2                                           0
# 14                             2                                           0
# 15                             2                                           0
# 16                             2                                           0
# 17                             2                                           0
# 18                             2                                           0
# 19                             2                                           0
# 20                             2                                           0
# 21                             2                                           0
# 22                             2                                           0
# 23                             2                                           0
# 24                             2                                           0
# 25                             2                                           0
# 26                             3                                           0
# 27                             2                                           0
# 28                             2                                           0
# 29                             2                                           0
# 30                             3                                           0
# 31                             2                                           0
# 32                             2                                           0
# 33                             2                                           0
# 34                             2                                           0
# 35                             2                                           0
# 36                             2                                           0
# 37                             2                                           0
# 38                             2                                           0
# 39                             3                                           0
# 40                             3                                           0
# 41                             3                                           0
# 42                             3                                           0
# 43                             3                                           0
# 44                             3                                           0
# 45                             3                                           0
# 46                             2                                           0
# 47                             2                                           0
# 48                             3                                           0
# 49                             3                                           0
# 50                             2                                           0
# 51                             2                                           0
# 52                             2                                           0
# 53                             2                                           0
# 54                             2                                           0
#
# [55 rows x 118 columns]

# %% [markdown]
# Seems like IPC API only has recent analyses. We can grab the older ones from the CH file on HDX.

# %%
blob_name = f"{PROJECT_PREFIX}/raw/ch/cadre_harmonise_caf_ipc_dec25_final.xlsx"
df_full = pd.read_excel(BytesIO(stratus.load_blob_data(blob_name)))

# %%
df_full.columns
# Out:
# Index(['adm0_name', 'adm0_pcod2', 'adm0_pcod3', 'adm0_5_name', 'adm0_5_pcod2',
#        'adm1_name', 'adm1_pcod2', 'adm1_5_name', 'adm1_5_pcod2', 'adm2_name',
#        'adm2_pcod2', 'adm2_5_name', 'adm2_5_pcod2', 'adm3_name', 'adm3_pcod2',
#        'exercise_code', 'exercise_label', 'exercise_year', 'chtype',
#        'reference_code', 'reference_label', 'reference_year', 'population',
#        'phase_class', 'phase1', 'phase2', 'phase3', 'phase4', 'phase5',
#        'phase35', 'foodconsumption_phase', 'livelihoods_phase',
#        'nutrition_phase', 'mortality_phase', 'FCG_Poor', 'FCG_Borderline',
#        'FCG_Acceptable', 'FCG_finalphase', 'HDDS_Phase1', 'HDDS_Phase2',
#        'HDDS_Phase3', 'HDDS_Phase4', 'HDDS_Phase5', 'HDDS_finalphase',
#        'HHS_Phase1', 'HHS_Phase2', 'HHS_Phase3', 'HHS_Phase4', 'HHS_Phase5',
#        'HHS_finalphase', 'LhHCSCat_NoStrategies', 'LhHCSCat_StressStrategies',
#        'LhHCSCat_CrisisStategies', 'LhHCSCat_EmergencyStrategies',
#        'LhHCSCat_finalphase', 'rCSI_Phase1', 'rCSI_Phase2', 'rCSI_Phase3',
#        'rCSI_finalphase', 'notes', 'usethisperiod'],
#       dtype='object')

# %%
df_mrt = df_full[df_full["adm0_pcod3"] == ISO3.upper()]

# %%
df_mrt["chtype"].value_counts()
# Out:
# chtype
# projected    743
# current      680
# Name: count, dtype: int64

# %%
df_mrt["reference_label"].value_counts()
# Out:
# reference_label
# Jun-Aug    730
# Sep-Dec    355
# Jan-May    338
# Name: count, dtype: int64

# %%
df_mrt["exercise_label"].value_counts()
# Out:
# exercise_label
# Sep-Dec    725
# Jan-May    698
# Name: count, dtype: int64

# %%
df_mrt[df_mrt["adm1_pcod2"] == "MR10"]["adm1_name"].unique()
# Out:
# array(['Nouakchott'], dtype=object)

# %%
adm1[adm1["adm1_src"] == "MR10"]
# Out:
#     fid          adm1_id adm1_src   adm1_name adm1_name1 adm1_name2  \
# 9  2038  MRT-20240402-10     MR10  Guidimagha       None       None
#
#         adm0_id adm0_src   adm0_name  adm0_name1  ...          region2_nm  \
# 9  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
#
#    region1_cd region1_nm status_cd status_nm    wld_date  wld_update wld_view  \
# 9           2     Africa         1     State  2025-02-24  2025-07-29     intl
#
#   wld_notes                                           geometry
# 9      None  MULTIPOLYGON (((-11.99044 14.76314, -11.98911 ...
#
# [1 rows x 39 columns]

# %% [markdown]
# Let's just merge and treat Nouakchott as a single adm1

# %%
nouak_row = adm1[adm1["adm1_name"].str.contains("Nouakchott")].dissolve()

# %%
nouak_row["adm1_name"] = "Nouakchott"

# %%
adm1_single_nouak = pd.concat(
    [adm1[~adm1["adm1_name"].str.contains("Nouakchott")], nouak_row]
)

# %%
adm1_single_nouak
# Out:
#      fid          adm1_id adm1_src           adm1_name adm1_name1 adm1_name2  \
# 0   2029  MRT-20240402-01     MR01        Hodh Chargui       None       None
# 1   2030  MRT-20240402-02     MR02      Hodh El Gharbi       None       None
# 2   2031  MRT-20240402-03     MR03              Assaba       None       None
# 3   2032  MRT-20240402-04     MR04              Gorgol       None       None
# 4   2033  MRT-20240402-05     MR05              Brakna       None       None
# 5   2034  MRT-20240402-06     MR06              Trarza       None       None
# 6   2035  MRT-20240402-07     MR07               Adrar       None       None
# 7   2036  MRT-20240402-08     MR08  Dakhlet Nouadhibou       None       None
# 8   2037  MRT-20240402-09     MR09              Tagant       None       None
# 9   2038  MRT-20240402-10     MR10          Guidimagha       None       None
# 10  2039  MRT-20240402-11     MR11       Tiris Zemmour       None       None
# 11  2040  MRT-20240402-12     MR12             Inchiri       None       None
# 0   2041  MRT-20240402-13     MR13          Nouakchott       None       None
#
#          adm0_id adm0_src   adm0_name  adm0_name1  ...          region2_nm  \
# 0   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 1   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 2   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 3   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 4   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 5   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 6   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 7   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 8   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 9   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 10  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 11  MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
# 0   MRT-20250729      MRT  Mauritania  Mauritania  ...  Sub-Saharan Africa
#
#     region1_cd region1_nm status_cd status_nm    wld_date  wld_update  \
# 0            2     Africa         1     State  2025-02-24  2025-07-29
# 1            2     Africa         1     State  2025-02-24  2025-07-29
# 2            2     Africa         1     State  2025-02-24  2025-07-29
# 3            2     Africa         1     State  2025-02-24  2025-07-29
# 4            2     Africa         1     State  2025-02-24  2025-07-29
# 5            2     Africa         1     State  2025-02-24  2025-07-29
# 6            2     Africa         1     State  2025-02-24  2025-07-29
# 7            2     Africa         1     State  2025-02-24  2025-07-29
# 8            2     Africa         1     State  2025-02-24  2025-07-29
# 9            2     Africa         1     State  2025-02-24  2025-07-29
# 10           2     Africa         1     State  2025-02-24  2025-07-29
# 11           2     Africa         1     State  2025-02-24  2025-07-29
# 0            2     Africa         1     State  2025-02-24  2025-07-29
#
#    wld_view wld_notes                                           geometry
# 0      intl      None  MULTIPOLYGON (((-5.58747 16.48706, -5.60347 16...
# 1      intl      None  MULTIPOLYGON (((-10.0498 15.36374, -10.04654 1...
# 2      intl      None  MULTIPOLYGON (((-10.58564 15.42909, -10.62056 ...
# 3      intl      None  MULTIPOLYGON (((-12.75489 15.13907, -12.75488 ...
# 4      intl      None  MULTIPOLYGON (((-13.70743 16.15393, -13.68799 ...
# 5      intl      None  MULTIPOLYGON (((-16.2873 16.50018, -16.2871 16...
# 6      intl      None  MULTIPOLYGON (((-13.33236 19.00029, -13.20623 ...
# 7      intl      None  MULTIPOLYGON (((-16.48909 19.62472, -16.48869 ...
# 8      intl      None  MULTIPOLYGON (((-11.52933 17.17609, -11.59948 ...
# 9      intl      None  MULTIPOLYGON (((-11.99044 14.76314, -11.98911 ...
# 10     intl      None  MULTIPOLYGON (((-6.56009 24.89802, -6.56685 24...
# 11     intl      None  MULTIPOLYGON (((-15.74314 19.27873, -15.77649 ...
# 0      intl      None  POLYGON ((-15.84522 17.98098, -15.84623 17.903...
#
# [13 rows x 39 columns]

# %%
group_cols = [
    "exercise_year",
    "exercise_label",
    "chtype",
    "reference_label",
    "reference_year",
    "adm1_name",
    "adm1_pcod2",
]

# %%
df_mrt_adm1 = df_mrt.groupby(group_cols).sum(numeric_only=True).reset_index()

# %% [markdown]
# Oh no it looks like `MR10` is for Nouakchott in this old version of CODAB. In the new version this is for Guidimagha. What a nightmare.

# %%
for x in df_mrt_adm1["adm1_pcod2"].unique():
    if x not in adm1["adm1_src"].unique():
        print(x)

# %%
cols = ["adm1_name", "adm1_pcod2"]
adm1[["adm1_src", "adm1_name"]].merge(
    df_mrt.groupby(cols).first().reset_index()[cols],
    left_on="adm1_src",
    right_on="adm1_pcod2",
    suffixes=("_codab", "_ipc"),
)
# Out:
#    adm1_src     adm1_name_codab       adm1_name_ipc adm1_pcod2
# 0      MR01        Hodh Chargui               Adrar       MR01
# 1      MR02      Hodh El Gharbi              Assaba       MR02
# 2      MR03              Assaba              Brakna       MR03
# 3      MR04              Gorgol  Dakhlet-Nouadhibou       MR04
# 4      MR05              Brakna              Gorgol       MR05
# 5      MR06              Trarza          Guidimakha       MR06
# 6      MR07               Adrar     Hodh Ech Chargi       MR07
# 7      MR08  Dakhlet Nouadhibou      Hodh El Gharbi       MR08
# 8      MR09              Tagant             Inchiri       MR09
# 9      MR10          Guidimagha          Nouakchott       MR10
# 10     MR11       Tiris Zemmour              Tagant       MR11
# 11     MR12             Inchiri       Tiris-Zemmour       MR12
# 12     MR13    Nouakchott Ouest              Trarza       MR13

# %%
df_mrt_adm1.columns
# Out:
# Index(['exercise_year', 'exercise_label', 'chtype', 'reference_label',
#        'reference_year', 'adm1_name', 'adm1_pcod2', 'adm0_5_pcod2',
#        'exercise_code', 'reference_code', 'population', 'phase_class',
#        'phase1', 'phase2', 'phase3', 'phase4', 'phase5', 'phase35',
#        'foodconsumption_phase', 'livelihoods_phase', 'nutrition_phase',
#        'mortality_phase', 'FCG_Poor', 'FCG_Borderline', 'FCG_Acceptable',
#        'FCG_finalphase', 'HDDS_Phase1', 'HDDS_Phase2', 'HDDS_Phase3',
#        'HDDS_Phase4', 'HDDS_Phase5', 'HDDS_finalphase', 'HHS_Phase1',
#        'HHS_Phase2', 'HHS_Phase3', 'HHS_Phase4', 'HHS_Phase5',
#        'HHS_finalphase', 'LhHCSCat_NoStrategies', 'LhHCSCat_StressStrategies',
#        'LhHCSCat_CrisisStategies', 'LhHCSCat_EmergencyStrategies',
#        'LhHCSCat_finalphase', 'rCSI_Phase1', 'rCSI_Phase2', 'rCSI_Phase3',
#        'rCSI_finalphase'],
#       dtype='object')

# %%
for x in [1, 2, 3, 4, 5, 35]:
    df_mrt_adm1[f"frac_phase{x}"] = (
        df_mrt_adm1[f"phase{x}"] / df_mrt_adm1["population"]
    )

# %%
df_mrt_adm1["reference_label"].unique()
# Out:
# array(['Jan-May', 'Jun-Aug', 'Sep-Dec'], dtype=object)

# %%
def ref_label_to_month(x):
    if x == "Jan-May":
        return 3
    elif x == "Jun-Aug":
        return 7
    elif x == "Sep-Dec":
        return 11
    else:
        raise ValueError("invalid reference_label")

# %%
df_mrt_adm1["reference_month"] = df_mrt_adm1["reference_label"].apply(
    ref_label_to_month
)

# %%
df_mrt_adm1["reference_date"] = df_mrt_adm1.apply(
    lambda row: datetime(
        year=row["reference_year"], month=row["reference_month"], day=1
    ),
    axis=1,
)

# %%
df_mrt_adm1_current = (
    df_mrt_adm1[df_mrt_adm1["chtype"] == "current"]
    .groupby(
        [
            "adm1_name",
            "adm1_pcod2",
            "exercise_year",
            "exercise_label",
            "reference_date",
        ]
    )
    .mean(numeric_only=True)
    .reset_index()
)

# %%
df_mrt_adm1_projected = (
    df_mrt_adm1[df_mrt_adm1["chtype"] == "projected"]
    .groupby(
        [
            "adm1_name",
            "adm1_pcod2",
            "exercise_year",
            "exercise_label",
            "reference_label",
            "reference_year",
            "reference_date",
        ]
    )
    .mean(numeric_only=True)
    .reset_index()
)

# %%
def french_thousands(x, pos):
    return f"{int(x):,}".replace(",", "\u202f")

# %%
def plot_stacked_phase35(df, pop_frac: bool = False):
    cols = (
        ["frac_phase3", "frac_phase4", "frac_phase5"]
        if pop_frac
        else ["phase3", "phase4", "phase5"]
    )
    fig, ax = plt.subplots()

    df.set_index("adm1_name")[cols].plot(
        kind="bar",
        stacked=True,
        ax=ax,
        color=[
            "darkorange",
            "crimson",
            "darkred",
        ],
    )
    ax.legend(
        [3, 4, 5],
        title="Phase CH",
    )
    ax.set_xlabel("Région")
    ylabel = "Fraction de population" if pop_frac else "Population"
    ax.set_ylabel(ylabel)
    if not pop_frac:
        ax.yaxis.set_major_formatter(FuncFormatter(french_thousands))
    [ax.spines[x].set_visible(False) for x in ["top", "right"]]
    return fig, ax

# %%
df_mrt_adm1_current["reference_year"].unique()
# Out:
# array([2014., 2015., 2016., 2017., 2018., 2019., 2020., 2021., 2022.,
#        2023., 2024., 2025.])

# %%
df_mrt_adm1_current_grouped = (
    df_mrt_adm1_current.groupby("adm1_name")
    .mean(numeric_only=True)
    .reset_index()
)

# %%
sel_adm1_names = [
    "Gorgol",
    "Guidimakha",
    "Hodh Ech Chargi",
    "Assaba",
    "Brakna",
    "Hodh El Gharbi",
]

# %%
fig, ax = plt.subplots(figsize=(7, 7), dpi=200)
for _, row in df_mrt_adm1_current_grouped.iterrows():
    ax.annotate(
        row["adm1_name"],
        row[["phase35", "frac_phase35"]],
        ha="center",
        va="center",
        fontweight="bold" if row["adm1_name"] in sel_adm1_names else "normal",
    )

ax.set_xlim(0, df_mrt_adm1_current_grouped["phase35"].max() * 1.1)
ax.set_ylim(0, df_mrt_adm1_current_grouped["frac_phase35"].max() * 1.1)

[ax.spines[x].set_visible(False) for x in ["top", "right"]]

ax.set_xlabel("Population en phase 3+")
ax.set_ylabel("Fraction de population en phase 3+")

ax.xaxis.set_major_formatter(FuncFormatter(french_thousands))

ax.set_title("Population en phase CH 3+\nMoyenne depuis 2014, toutes périodes")
# Out:
# Text(0.5, 1.0, 'Population en phase CH 3+\nMoyenne depuis 2014, toutes périodes')

# %%
fig, ax = plot_stacked_phase35(df_mrt_adm1_current_grouped, pop_frac=True)
ax.set_title(
    "Population actuelle en phase CH 3+\nMoyenne depuis 2014, toutes périodes"
)
# Out:
# Text(0.5, 1.0, 'Population actuelle en phase CH 3+\nMoyenne depuis 2014, toutes périodes')

# %%
fig, ax = plot_stacked_phase35(df_mrt_adm1_current_grouped)
ax.set_title(
    "Population actuelle en phase CH 3+\nMoyenne depuis 2014, toutes périodes"
)
# Out:
# Text(0.5, 1.0, 'Population actuelle en phase CH 3+\nMoyenne depuis 2014, toutes périodes')

# %%
fig, ax = plot_stacked_phase35(
    df_mrt_adm1_projected.groupby("adm1_name")
    .mean(numeric_only=True)
    .reset_index()
)
ax.set_title(
    "Population projetée en phase CH 3+\nMoyenne depuis 2014, toutes périodes"
)
# Out:
# Text(0.5, 1.0, 'Population projetée en phase CH 3+\nMoyenne depuis 2014, toutes périodes')

# %%
min_year = 2020
fig, ax = plot_stacked_phase35(
    df_mrt_adm1_current[df_mrt_adm1_current["reference_year"] >= min_year]
    .groupby("adm1_name")
    .mean(numeric_only=True)
    .reset_index()
)
ax.set_title(
    f"Population actuelle en phase CH 3+\nMoyenne depuis {min_year}, toutes périodes"
)
# Out:
# Text(0.5, 1.0, 'Population actuelle en phase CH 3+\nMoyenne depuis 2020, toutes périodes')

# %%
df_mrt_adm1_current
# Out:
#     adm1_name adm1_pcod2  exercise_year exercise_label reference_date  \
# 0       Adrar       MR01           2014        Jan-May     2014-03-01
# 1       Adrar       MR01           2014        Sep-Dec     2014-11-01
# 2       Adrar       MR01           2015        Jan-May     2015-03-01
# 3       Adrar       MR01           2015        Sep-Dec     2015-11-01
# 4       Adrar       MR01           2016        Jan-May     2016-03-01
# ..        ...        ...            ...            ...            ...
# 293    Trarza       MR13           2023        Sep-Dec     2023-11-01
# 294    Trarza       MR13           2024        Jan-May     2024-03-01
# 295    Trarza       MR13           2024        Sep-Dec     2024-11-01
# 296    Trarza       MR13           2025        Jan-May     2025-03-01
# 297    Trarza       MR13           2025        Sep-Dec     2025-11-01
#
#      reference_year  adm0_5_pcod2  exercise_code  reference_code  population  \
# 0            2014.0           0.0            2.0             2.0     62678.0
# 1            2014.0           0.0            1.0             1.0     62132.0
# 2            2015.0           0.0            2.0             2.0     62658.0
# 3            2015.0           0.0            1.0             1.0     63715.0
# 4            2016.0           0.0            2.0             2.0     64250.0
# ..              ...           ...            ...             ...         ...
# 293          2023.0           0.0            7.0             7.0    327201.0
# 294          2024.0           0.0           14.0            14.0    327199.0
# 295          2024.0           0.0            1.0             1.0    323903.0
# 296          2025.0           0.0           14.0            14.0    323903.0
# 297          2025.0           0.0            7.0             7.0    350306.0
#
#      ...  rCSI_Phase2  rCSI_Phase3  rCSI_finalphase  frac_phase1  frac_phase2  \
# 0    ...          0.0          0.0              0.0     0.799994     0.200006
# 1    ...          0.0          0.0              0.0     0.789995     0.169993
# 2    ...          0.0          0.0              0.0     0.810000     0.179993
# 3    ...          0.0          0.0              0.0     0.829993     0.120003
# 4    ...          0.0          0.0              0.0     0.830008     0.150008
# ..   ...          ...          ...              ...          ...          ...
# 293  ...          0.0          0.0              0.0     0.815028     0.166149
# 294  ...          0.0          0.0              0.0     0.729932     0.183913
# 295  ...          0.0          0.0              0.0     0.890001     0.099999
# 296  ...          0.0          0.0              0.0     0.764158     0.174386
# 297  ...          0.0          0.0              0.0     0.813899     0.148058
#
#      frac_phase3  frac_phase4  frac_phase5  frac_phase35  reference_month
# 0       0.000000          0.0          0.0      0.000000              3.0
# 1       0.039995          0.0          0.0      0.039995             11.0
# 2       0.010007          0.0          0.0      0.010007              3.0
# 3       0.050004          0.0          0.0      0.050004             11.0
# 4       0.020000          0.0          0.0      0.020000              3.0
# ..           ...          ...          ...           ...              ...
# 293     0.018823          0.0          0.0      0.018823             11.0
# 294     0.086152          0.0          0.0      0.086152              3.0
# 295     0.010000          0.0          0.0      0.010000             11.0
# 296     0.061457          0.0          0.0      0.061457              3.0
# 297     0.038044          0.0          0.0      0.038044             11.0
#
# [298 rows x 53 columns]

# %%
df_mrt_adm1_current.columns
# Out:
# Index(['adm1_name', 'adm1_pcod2', 'exercise_year', 'exercise_label',
#        'reference_date', 'reference_year', 'adm0_5_pcod2', 'exercise_code',
#        'reference_code', 'population', 'phase_class', 'phase1', 'phase2',
#        'phase3', 'phase4', 'phase5', 'phase35', 'foodconsumption_phase',
#        'livelihoods_phase', 'nutrition_phase', 'mortality_phase', 'FCG_Poor',
#        'FCG_Borderline', 'FCG_Acceptable', 'FCG_finalphase', 'HDDS_Phase1',
#        'HDDS_Phase2', 'HDDS_Phase3', 'HDDS_Phase4', 'HDDS_Phase5',
#        'HDDS_finalphase', 'HHS_Phase1', 'HHS_Phase2', 'HHS_Phase3',
#        'HHS_Phase4', 'HHS_Phase5', 'HHS_finalphase', 'LhHCSCat_NoStrategies',
#        'LhHCSCat_StressStrategies', 'LhHCSCat_CrisisStategies',
#        'LhHCSCat_EmergencyStrategies', 'LhHCSCat_finalphase', 'rCSI_Phase1',
#        'rCSI_Phase2', 'rCSI_Phase3', 'rCSI_finalphase', 'frac_phase1',
#        'frac_phase2', 'frac_phase3', 'frac_phase4', 'frac_phase5',
#        'frac_phase35', 'reference_month'],
#       dtype='object')

# %%
# Prep data
df = df_mrt_adm1_current.copy()
df["reference_date"] = pd.to_datetime(df["reference_date"])
df[["phase3", "phase4", "phase5"]] = df[["phase3", "phase4", "phase5"]].apply(
    pd.to_numeric, errors="coerce"
)
df = df.dropna(
    subset=["reference_date", "adm1_name", "phase3", "phase4", "phase5"]
)

adm1_list = sel_adm1_names

fig, axes = plt.subplots(
    nrows=len(adm1_list),
    ncols=1,
    figsize=(10, 1.8 * len(adm1_list)),
    sharex=True,
    sharey=True,
    dpi=200,
)

colors = [
    "darkorange",
    "crimson",
    "darkred",
]
labels = [3, 4, 5]

# Global y max for consistent scaling
df["total"] = df[["phase3", "phase4", "phase5"]].sum(axis=1)
ymax = df["total"].max()

for ax, adm1 in zip(axes, adm1_list):
    df_sub = df[df["adm1_name"] == adm1].sort_values("reference_date")

    x = df_sub["reference_date"]
    y1 = df_sub["phase3"].values
    y2 = df_sub["phase4"].values
    y3 = df_sub["phase5"].values

    # Only show legend once, but always pass iterable
    this_labels = labels if ax is axes[0] else ["", "", ""]

    ax.stackplot(x, y1, y2, y3, colors=colors, labels=this_labels)

    ax.set_xlim(pd.to_datetime(["2014-03-01", "2025-11-01"]))
    ax.set_ylim(0, ymax * 1.1)
    ax.set_ylabel(adm1, rotation=0, ha="right", va="center")
    ax.yaxis.set_major_formatter(FuncFormatter(french_thousands))
    [ax.spines[x].set_visible(False) for x in ["top", "right"]]


axes[-1].set_xlabel("Date")
axes[-1].xaxis.set_major_locator(mdates.YearLocator())
axes[-1].xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
axes[0].legend(title="Phase CH", loc="upper right", bbox_to_anchor=(1, 1.2))

fig.suptitle(
    "Population en phase 3+ historique\n6 régions avec historiquement les plus hauts niveaux",
    fontsize=14,
    y=0.95,
)
# Out:
# Text(0.5, 0.95, 'Population en phase 3+ historique\n6 régions avec historiquement les plus hauts niveaux')
